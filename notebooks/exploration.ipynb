# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from mistralai.client import Mistral
import script.utils as utils

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_colwidth', None)

# %%
events = pd.read_json('../data/__raw/events.json')

# %%
events.head(1)
# Out:
#         uid  \
# 0  66740915
#
#                                                                           slug  \
# 0  jeudi-de-linterim-avec-aquila-rh-btp-industriemaintenance-automobile-875071
#
#                                                                                                               canonicalurl  \
# 0  https://openagenda.com/francetravail/events/jeudi-de-linterim-avec-aquila-rh-btp-industriemaintenance-automobile-875071
#
#                                                                      title_fr  \
# 0  Jeudi de l'Intérim avec Aquila RH : BTP, Industrie/maintenance, Automobile
#
#                                                                                                                   description_fr  \
# 0  Aucun poste administratif proposé Rencontrez un recruteur, échangez sur votre projet et accédez à des opportunités concrètes.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             longdescription_fr  \
# 0  <p>Aucun poste administratif proposé Rencontrez un recruteur, échangez sur votre projet et accédez à des opportunités concrètes. Vous êtes professionnel du bâtiment, de l'industrie ou de la maintenance et à la recherche d'une mission ? Venez rencontrer Aquila RH lors d'un Jeudi de l'Intérim en agence France Travail ! Postes à pourvoir : BTP : Plaquiste confirmé (min. N3P2) Peintre confirmé (min. N3P2) Maçon Coffreur/bancheur confirmé (min. N3P2) Couvreur confirmé (min. N3P1) Maintenance / Industrie</p>
#
#   conditions_fr                             keywords_fr  \
# 0           NaN  [INTERIM, #TousMobilisés, Recrutement]
#
#                                                                              image  \
# 0  https://cdn.openagenda.com/main/445fffe929e24ce48469f6e6f5b92ddb.base.image.jpg
#
#   imagecredits  \
# 0          NaN
#
#                                                                           thumbnail  \
# 0  https://cdn.openagenda.com/main/445fffe929e24ce48469f6e6f5b92ddb.thumb.image.jpg
#
#                                                                      originalimage  \
# 0  https://cdn.openagenda.com/main/445fffe929e24ce48469f6e6f5b92ddb.full.image.jpg
#
#                    updatedat         daterange_fr            firstdate_begin  \
# 0  2026-05-21T07:11:38+00:00  Jeudi 21 mai, 11h00  2026-05-21T09:00:00+00:00
#
#                firstdate_end             lastdate_begin  \
# 0  2026-05-21T10:00:00+00:00  2026-05-21T09:00:00+00:00
#
#                 lastdate_end  \
# 0  2026-05-21T10:00:00+00:00
#
#                                                                         timings  \
# 0  [{"begin": "2026-05-21T11:00:00+02:00", "end": "2026-05-21T12:00:00+02:00"}]
#
#   accessibility accessibility_label_fr  location_uid  \
# 0           NaN                   None      59206963
#
#                    location_coordinates                  location_name  \
# 0  {'lon': -1.115502, 'lat': 46.150688}  Agence LA ROCHELLE-VILLENEUVE
#
#     location_address location_district  location_insee  location_postalcode  \
# 0  17000 La Rochelle               NaN             NaN                17000
#
#   location_city location_department     location_region location_countrycode  \
# 0   La Rochelle   Charente-Maritime  Nouvelle-Aquitaine                   FR
#
#   location_image location_imagecredits location_phone location_website  \
# 0            NaN                   NaN            NaN              NaN
#
#   location_links location_tags location_description_fr location_access_fr  \
# 0            NaN           NaN                     NaN                NaN
#
#                                                                                                                                                                                                                      attendancemode  \
# 0  {"id": 1, "label": {"fr": "Sur place", "en": "In situ", "it": "In presenza", "es": "Desconnectad", "de": "Offline", "br": "War al lec\u2019h", "io": "crwdns14266:0crwdne14266:0", "oc": "Sus pla\u00e7a", "nl": "Ter plaatse"}}
#
#   onlineaccesslink  \
# 0              NaN
#
#                                                                                                                                                                            status  \
# 0  {"id": 1, "label": {"fr": "Programm\u00e9", "en": "Scheduled", "io": "crwdns16100:0crwdne16100:0", "es": "Programado", "oc": "Programat", "nl": "Gepland", "br": "Raktreset"}}
#
#    age_min  age_max             originagenda_title  originagenda_uid  \
# 0      NaN      NaN  Mes événements France Travail          38495884
#
#    contributor_email  contributor_contactnumber  contributor_contactname  \
# 0                NaN                        NaN                      NaN
#
#    contributor_contactposition  contributor_organization  category  \
# 0                          NaN                       NaN       NaN
#
#            country_fr  \
# 0  France (Métropole)
#
#                                                                                                          registration  \
# 0  [{"type": "link", "value": "https://mesevenementsemploi.francetravail.fr/mes-evenements-emploi/evenement/659256"}]
#
#   links
# 0   NaN

# %%
events.columns.tolist()
# Out:
# ['uid',
#  'slug',
#  'canonicalurl',
#  'title_fr',
#  'description_fr',
#  'longdescription_fr',
#  'conditions_fr',
#  'keywords_fr',
#  'image',
#  'imagecredits',
#  'thumbnail',
#  'originalimage',
#  'updatedat',
#  'daterange_fr',
#  'firstdate_begin',
#  'firstdate_end',
#  'lastdate_begin',
#  'lastdate_end',
#  'timings',
#  'accessibility',
#  'accessibility_label_fr',
#  'location_uid',
#  'location_coordinates',
#  'location_name',
#  'location_address',
#  'location_district',
#  'location_insee',
#  'location_postalcode',
#  'location_city',
#  'location_department',
#  'location_region',
#  'location_countrycode',
#  'location_image',
#  'location_imagecredits',
#  'location_phone',
#  'location_website',
#  'location_links',
#  'location_tags',
#  'location_description_fr',
#  'location_access_fr',
#  'attendancemode',
#  'onlineaccesslink',
#  'status',
#  'age_min',
#  'age_max',
#  'originagenda_title',
#  'originagenda_uid',
#  'contributor_email',
#  'contributor_contactnumber',
#  'contributor_contactname',
#  'contributor_contactposition',
#  'contributor_organization',
#  'category',
#  'country_fr',
#  'registration',
#  'links']

# %%
e = events[(events['firstdate_begin'] > '2026-05-01') & (events['firstdate_begin'] < '2026-05-10')]
e['title_fr']
# Out:
# 2                                                        Comptoir des offres - mise en relation avec des entreprises qui recrutent !
# 15                                                                                                       Atelier ludique de mobilité
# 20                                                                        Les clés pour ton avenir - le Service Militaire Volontaire
# 43                                                                                                                      Vêlo en Fête
# 62                                                                               Nouvelles pistes cyclables au Sud : quelle chance !
# 66                                                                                    Atelier : les aides à la création d'entreprise
# 114                                                                              NOUVELLES PISTES CYCLABLES AU SUD : QUELLE CHANCE !
# 141                                                      Comptoir des offres - mise en relation avec des entreprises qui recrutent !
# 159                                                                               Présentation de l'application TRAVAILLER EN FRANCE
# 181                                                                                         DEVENEZ ANIMATEUR EN CENTRE DE LOISIRS !
# 206                                                                                        FATOUMATA DIAWARA + OKALI + TITOUAN L.C.S
# 234                                                                                    Les trésors du canal de Rompsay et de Périgny
# 306                                                                                       Vis ma Vie d'apprenti mécanicien(ne) Cycle
# 312                                                      Comptoir des offres - mise en relation avec des entreprises qui recrutent !
# 324                                                                                             AFTERWORK - ALUMNI & ENTREPRISE VELO
# 332                                                                                                     Parcours "ECLAURE" 50 ans et
# 347    ATELIER MOBILITE et STAND DE JEUX de sensibilisation à la réglementation à la sécurité routière, aux bonnes pratiques à vélos
# 399                                                                                                            VIS MA VIE D'APPRENTI
# 403                                                         Rencontre avec l'Association Intermédiaire ADEF pour aller vers l'emploi
# 418                                                                               Présentation PREPA COMPETENCES au Café de l'Azimut
# 435                                 Atelier Flash : Valorisez votre profil candidat et découvrez l'IA au service de vos candidatures
# 449                                                                                                  La Bourse aux vélos des Cabanes
# 453                                                                                                             Visite restaurateurs
# 483                                                                              Rencontre avec COHESION 17 pour aller vers l'emploi
# Name: title_fr, dtype: str
